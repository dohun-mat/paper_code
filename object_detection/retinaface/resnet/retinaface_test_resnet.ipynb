# %%
from __future__ import print_function
import os
import argparse
import torch
import torch.backends.cudnn as cudnn
import numpy as np
# from data import cfg_mnet, cfg_re50
# from layers.functions.prior_box import PriorBox
# from utils.nms.py_cpu_nms import py_cpu_nms
import cv2
# from models.retinaface import RetinaFace
# from utils.box_utils import decode, decode_landm
# from utils.timer import Timer

# %%
# --------------------------------------------------------
# Fast R-CNN
# Copyright (c) 2015 Microsoft
# Licensed under The MIT License [see LICENSE for details]
# Written by Ross Girshick
# --------------------------------------------------------

import time


class Timer(object):
    """A simple timer."""
    def __init__(self):
        self.total_time = 0.
        self.calls = 0
        self.start_time = 0.
        self.diff = 0.
        self.average_time = 0.

    def tic(self):
        # using time.time instead of time.clock because time time.clock
        # does not normalize for multithreading
        self.start_time = time.time()

    def toc(self, average=True):
        self.diff = time.time() - self.start_time
        self.total_time += self.diff
        self.calls += 1
        self.average_time = self.total_time / self.calls
        if average:
            return self.average_time
        else:
            return self.diff

    def clear(self):
        self.total_time = 0.
        self.calls = 0
        self.start_time = 0.
        self.diff = 0.
        self.average_time = 0.

# %%
def decode(loc, priors, variances):
    """Decode locations from predictions using priors to undo
    the encoding we did for offset regression at train time.
    Args:
        loc (tensor): location predictions for loc layers,
            Shape: [num_priors,4]
        priors (tensor): Prior boxes in center-offset form.
            Shape: [num_priors,4].
        variances: (list[float]) Variances of priorboxes
    Return:
        decoded bounding box predictions
    """

    boxes = torch.cat((
        priors[:, :2] + loc[:, :2] * variances[0] * priors[:, 2:],
        priors[:, 2:] * torch.exp(loc[:, 2:] * variances[1])), 1)
    boxes[:, :2] -= boxes[:, 2:] / 2
    boxes[:, 2:] += boxes[:, :2]
    return boxes

def decode_landm(pre, priors, variances):
    """Decode landm from predictions using priors to undo
    the encoding we did for offset regression at train time.
    Args:
        pre (tensor): landm predictions for loc layers,
            Shape: [num_priors,10]
        priors (tensor): Prior boxes in center-offset form.
            Shape: [num_priors,4].
        variances: (list[float]) Variances of priorboxes
    Return:
        decoded landm predictions
    """
    landms = torch.cat((priors[:, :2] + pre[:, :2] * variances[0] * priors[:, 2:],
                        priors[:, :2] + pre[:, 2:4] * variances[0] * priors[:, 2:],
                        priors[:, :2] + pre[:, 4:6] * variances[0] * priors[:, 2:],
                        priors[:, :2] + pre[:, 6:8] * variances[0] * priors[:, 2:],
                        priors[:, :2] + pre[:, 8:10] * variances[0] * priors[:, 2:],
                        ), dim=1)
    return landms

# %%
import time
import torch
import torch.nn as nn
import torchvision.models._utils as _utils
import torchvision.models as models
import torch.nn.functional as F
from torch.autograd import Variable

def conv_bn(inp, oup, stride = 1, leaky = 0):
    return nn.Sequential(
        nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
        nn.BatchNorm2d(oup),
        nn.LeakyReLU(negative_slope=leaky, inplace=True)
    )

def conv_bn_no_relu(inp, oup, stride):
    return nn.Sequential(
        nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
        nn.BatchNorm2d(oup),
    )

def conv_bn1X1(inp, oup, stride, leaky=0):
    return nn.Sequential(
        nn.Conv2d(inp, oup, 1, stride, padding=0, bias=False),
        nn.BatchNorm2d(oup),
        nn.LeakyReLU(negative_slope=leaky, inplace=True)
    )

def conv_dw(inp, oup, stride, leaky=0.1):
    return nn.Sequential(
        nn.Conv2d(inp, inp, 3, stride, 1, groups=inp, bias=False),
        nn.BatchNorm2d(inp),
        nn.LeakyReLU(negative_slope= leaky,inplace=True),

        nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
        nn.BatchNorm2d(oup),
        nn.LeakyReLU(negative_slope= leaky,inplace=True),
    )

class SSH(nn.Module):
    def __init__(self, in_channel, out_channel):
        super(SSH, self).__init__()
        assert out_channel % 4 == 0
        leaky = 0
        if (out_channel <= 64):
            leaky = 0.1
        self.conv3X3 = conv_bn_no_relu(in_channel, out_channel//2, stride=1)

        self.conv5X5_1 = conv_bn(in_channel, out_channel//4, stride=1, leaky = leaky)
        self.conv5X5_2 = conv_bn_no_relu(out_channel//4, out_channel//4, stride=1)

        self.conv7X7_2 = conv_bn(out_channel//4, out_channel//4, stride=1, leaky = leaky)
        self.conv7x7_3 = conv_bn_no_relu(out_channel//4, out_channel//4, stride=1)

    def forward(self, input):
        conv3X3 = self.conv3X3(input)

        conv5X5_1 = self.conv5X5_1(input)
        conv5X5 = self.conv5X5_2(conv5X5_1)

        conv7X7_2 = self.conv7X7_2(conv5X5_1)
        conv7X7 = self.conv7x7_3(conv7X7_2)

        out = torch.cat([conv3X3, conv5X5, conv7X7], dim=1)
        out = F.relu(out)
        return out

class FPN(nn.Module):
    def __init__(self,in_channels_list,out_channels):
        super(FPN,self).__init__()
        leaky = 0
        if (out_channels <= 64):
            leaky = 0.1
        self.output1 = conv_bn1X1(in_channels_list[0], out_channels, stride = 1, leaky = leaky)
        self.output2 = conv_bn1X1(in_channels_list[1], out_channels, stride = 1, leaky = leaky)
        self.output3 = conv_bn1X1(in_channels_list[2], out_channels, stride = 1, leaky = leaky)

        self.merge1 = conv_bn(out_channels, out_channels, leaky = leaky)
        self.merge2 = conv_bn(out_channels, out_channels, leaky = leaky)

    def forward(self, input):
        # names = list(input.keys())
        input = list(input.values())

        output1 = self.output1(input[0])
        output2 = self.output2(input[1])
        output3 = self.output3(input[2])

        up3 = F.interpolate(output3, size=[output2.size(2), output2.size(3)], mode="nearest")
        output2 = output2 + up3
        output2 = self.merge2(output2)

        up2 = F.interpolate(output2, size=[output1.size(2), output1.size(3)], mode="nearest")
        output1 = output1 + up2
        output1 = self.merge1(output1)

        out = [output1, output2, output3]
        return out



class MobileNetV1(nn.Module):
    def __init__(self):
        super(MobileNetV1, self).__init__()
        self.stage1 = nn.Sequential(
            conv_bn(3, 8, 2, leaky = 0.1),    # 3
            conv_dw(8, 16, 1),   # 7
            conv_dw(16, 32, 2),  # 11
            conv_dw(32, 32, 1),  # 19
            conv_dw(32, 64, 2),  # 27
            conv_dw(64, 64, 1),  # 43
        )
        self.stage2 = nn.Sequential(
            conv_dw(64, 128, 2),  # 43 + 16 = 59
            conv_dw(128, 128, 1), # 59 + 32 = 91
            conv_dw(128, 128, 1), # 91 + 32 = 123
            conv_dw(128, 128, 1), # 123 + 32 = 155
            conv_dw(128, 128, 1), # 155 + 32 = 187
            conv_dw(128, 128, 1), # 187 + 32 = 219
        )
        self.stage3 = nn.Sequential(
            conv_dw(128, 256, 2), # 219 +3 2 = 241
            conv_dw(256, 256, 1), # 241 + 64 = 301
        )
        self.avg = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(256, 1000)

    def forward(self, x):
        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.avg(x)
        # x = self.model(x)
        x = x.view(-1, 256)
        x = self.fc(x)
        return x

# %%
import torch
import torch.nn as nn
import torchvision.models.detection.backbone_utils as backbone_utils
import torchvision.models._utils as _utils
import torch.nn.functional as F
from collections import OrderedDict

# from models.net import MobileNetV1 as MobileNetV1
# from models.net import FPN as FPN
# from models.net import SSH as SSH



class ClassHead(nn.Module):
    def __init__(self,inchannels=512,num_anchors=3):
        super(ClassHead,self).__init__()
        self.num_anchors = num_anchors
        self.conv1x1 = nn.Conv2d(inchannels,self.num_anchors*2,kernel_size=(1,1),stride=1,padding=0)

    def forward(self,x):
        out = self.conv1x1(x)
        out = out.permute(0,2,3,1).contiguous()
        
        return out.view(out.shape[0], -1, 2)

class BboxHead(nn.Module):
    def __init__(self,inchannels=512,num_anchors=3):
        super(BboxHead,self).__init__()
        self.conv1x1 = nn.Conv2d(inchannels,num_anchors*4,kernel_size=(1,1),stride=1,padding=0)

    def forward(self,x):
        out = self.conv1x1(x)
        out = out.permute(0,2,3,1).contiguous()

        return out.view(out.shape[0], -1, 4)

class LandmarkHead(nn.Module):
    def __init__(self,inchannels=512,num_anchors=3):
        super(LandmarkHead,self).__init__()
        self.conv1x1 = nn.Conv2d(inchannels,num_anchors*10,kernel_size=(1,1),stride=1,padding=0)

    def forward(self,x):
        out = self.conv1x1(x)
        out = out.permute(0,2,3,1).contiguous()

        return out.view(out.shape[0], -1, 10)

class RetinaFace(nn.Module):
    def __init__(self, cfg = None, phase = 'train'):
        """
        :param cfg:  Network related settings.
        :param phase: train or test.
        """
        super(RetinaFace,self).__init__()
        self.phase = phase
        backbone = None
        if cfg['name'] == 'mobilenet0.25':
            backbone = MobileNetV1()
            if cfg['pretrain']:
                checkpoint = torch.load("./weights/mobilenetV1X0.25_pretrain.tar", map_location=torch.device('cpu'))
                from collections import OrderedDict
                new_state_dict = OrderedDict()
                for k, v in checkpoint['state_dict'].items():
                    name = k[7:]  # remove module.
                    new_state_dict[name] = v
                # load params
                backbone.load_state_dict(new_state_dict)
        elif cfg['name'] == 'Resnet50':
            import torchvision.models as models
            backbone = models.resnet50(pretrained=cfg['pretrain'])

        self.body = _utils.IntermediateLayerGetter(backbone, cfg['return_layers'])
        in_channels_stage2 = cfg['in_channel']
        in_channels_list = [
            in_channels_stage2 * 2,
            in_channels_stage2 * 4,
            in_channels_stage2 * 8,
        ]
        out_channels = cfg['out_channel']
        self.fpn = FPN(in_channels_list,out_channels)
        self.ssh1 = SSH(out_channels, out_channels)
        self.ssh2 = SSH(out_channels, out_channels)
        self.ssh3 = SSH(out_channels, out_channels)

        self.ClassHead = self._make_class_head(fpn_num=3, inchannels=cfg['out_channel'])
        self.BboxHead = self._make_bbox_head(fpn_num=3, inchannels=cfg['out_channel'])
        self.LandmarkHead = self._make_landmark_head(fpn_num=3, inchannels=cfg['out_channel'])

    def _make_class_head(self,fpn_num=3,inchannels=64,anchor_num=2):
        classhead = nn.ModuleList()
        for i in range(fpn_num):
            classhead.append(ClassHead(inchannels,anchor_num))
        return classhead
    
    def _make_bbox_head(self,fpn_num=3,inchannels=64,anchor_num=2):
        bboxhead = nn.ModuleList()
        for i in range(fpn_num):
            bboxhead.append(BboxHead(inchannels,anchor_num))
        return bboxhead

    def _make_landmark_head(self,fpn_num=3,inchannels=64,anchor_num=2):
        landmarkhead = nn.ModuleList()
        for i in range(fpn_num):
            landmarkhead.append(LandmarkHead(inchannels,anchor_num))
        return landmarkhead

    def forward(self,inputs):
        out = self.body(inputs)

        # FPN
        fpn = self.fpn(out)

        # SSH
        feature1 = self.ssh1(fpn[0])
        feature2 = self.ssh2(fpn[1])
        feature3 = self.ssh3(fpn[2])
        features = [feature1, feature2, feature3]

        bbox_regressions = torch.cat([self.BboxHead[i](feature) for i, feature in enumerate(features)], dim=1)
        classifications = torch.cat([self.ClassHead[i](feature) for i, feature in enumerate(features)],dim=1)
        ldm_regressions = torch.cat([self.LandmarkHead[i](feature) for i, feature in enumerate(features)], dim=1)

        if self.phase == 'train':
            output = (bbox_regressions, classifications, ldm_regressions)
        else:
            output = (bbox_regressions, F.softmax(classifications, dim=-1), ldm_regressions)
        return output

# %%
# --------------------------------------------------------
# Fast R-CNN
# Copyright (c) 2015 Microsoft
# Licensed under The MIT License [see LICENSE for details]
# Written by Ross Girshick
# --------------------------------------------------------

import numpy as np

def py_cpu_nms(dets, thresh):
    """Pure Python NMS baseline."""
    x1 = dets[:, 0]
    y1 = dets[:, 1]
    x2 = dets[:, 2]
    y2 = dets[:, 3]
    scores = dets[:, 4]

    areas = (x2 - x1 + 1) * (y2 - y1 + 1)
    order = scores.argsort()[::-1]

    keep = []
    while order.size > 0:
        i = order[0]
        keep.append(i)
        xx1 = np.maximum(x1[i], x1[order[1:]])
        yy1 = np.maximum(y1[i], y1[order[1:]])
        xx2 = np.minimum(x2[i], x2[order[1:]])
        yy2 = np.minimum(y2[i], y2[order[1:]])

        w = np.maximum(0.0, xx2 - xx1 + 1)
        h = np.maximum(0.0, yy2 - yy1 + 1)
        inter = w * h
        ovr = inter / (areas[i] + areas[order[1:]] - inter)

        inds = np.where(ovr <= thresh)[0]
        order = order[inds + 1]

    return keep

# %%
import torch
from itertools import product as product
import numpy as np
from math import ceil


class PriorBox(object):
    def __init__(self, cfg, image_size=None, phase='train'):
        super(PriorBox, self).__init__()
        self.min_sizes = cfg['min_sizes']
        self.steps = cfg['steps']
        self.clip = cfg['clip']
        self.image_size = image_size
        self.feature_maps = [[ceil(self.image_size[0]/step), ceil(self.image_size[1]/step)] for step in self.steps]
        self.name = "s"

    def forward(self):
        anchors = []
        for k, f in enumerate(self.feature_maps):
            min_sizes = self.min_sizes[k]
            for i, j in product(range(f[0]), range(f[1])):
                for min_size in min_sizes:
                    s_kx = min_size / self.image_size[1]
                    s_ky = min_size / self.image_size[0]
                    dense_cx = [x * self.steps[k] / self.image_size[1] for x in [j + 0.5]]
                    dense_cy = [y * self.steps[k] / self.image_size[0] for y in [i + 0.5]]
                    for cy, cx in product(dense_cy, dense_cx):
                        anchors += [cx, cy, s_kx, s_ky]

        # back to torch land
        output = torch.Tensor(anchors).view(-1, 4)
        if self.clip:
            output.clamp_(max=1, min=0)
        return output

# %%
cfg_mnet = {
    'name': 'mobilenet0.25',
    'min_sizes': [[16, 32], [64, 128], [256, 512]],
    'steps': [8, 16, 32],
    'variance': [0.1, 0.2],
    'clip': False,
    'loc_weight': 2.0,
    'gpu_train': True,
    'batch_size': 32,
    'ngpu': 1,
    'epoch': 250,
    'decay1': 190,
    'decay2': 220,
    'image_size': 640,
    'pretrain': True,
    'return_layers': {'stage1': 1, 'stage2': 2, 'stage3': 3},
    'in_channel': 32,
    'out_channel': 64
}

# %%
cfg_re50 = {
    'name': 'Resnet50',
    'min_sizes': [[16, 32], [64, 128], [256, 512]],
    'steps': [8, 16, 32],
    'variance': [0.1, 0.2],
    'clip': False,
    'loc_weight': 2.0,
    'gpu_train': True,
    'batch_size': 24,
    'ngpu': 4,
    'epoch': 100,
    'decay1': 70,
    'decay2': 90,
    'image_size': 840,
    'pretrain': True,
    'return_layers': {'layer2': 1, 'layer3': 2, 'layer4': 3},
    'in_channel': 256,
    'out_channel': 256
}

# %%
import easydict

args = easydict.EasyDict({
    'trained_model' : './weights/Resnet50_Final.pth',
    'network' : 'resnet50',
    'origin_size' :  True,
    'save_folder' : './widerface_evaluate/widerface_txt/',
    'cpu' : False,
    'dataset_folder' : './widerface/val/images/',
    'confidence_threshold' : 0.02,
    'top_k' : 5000,
    'nms_threshold' : 0.4,
    'keep_top_k' : '750',
    'save_image' : True,
    'vis_thres' : 0.5
   })

# %%
def check_keys(model, pretrained_state_dict):
    ckpt_keys = set(pretrained_state_dict.keys())
    model_keys = set(model.state_dict().keys())
    used_pretrained_keys = model_keys & ckpt_keys
    unused_pretrained_keys = ckpt_keys - model_keys
    missing_keys = model_keys - ckpt_keys
    print('Missing keys:{}'.format(len(missing_keys)))
    print('Unused checkpoint keys:{}'.format(len(unused_pretrained_keys)))
    print('Used keys:{}'.format(len(used_pretrained_keys)))
    assert len(used_pretrained_keys) > 0, 'load NONE from pretrained checkpoint'
    return True


def remove_prefix(state_dict, prefix):
    ''' Old style model is stored with all names of parameters sharing common prefix 'module.' '''
    print('remove prefix \'{}\''.format(prefix))
    f = lambda x: x.split(prefix, 1)[-1] if x.startswith(prefix) else x
    return {f(key): value for key, value in state_dict.items()}


def load_model(model, pretrained_path, load_to_cpu):
    print('Loading pretrained model from {}'.format(pretrained_path))
    if load_to_cpu:
        pretrained_dict = torch.load(pretrained_path, map_location=lambda storage, loc: storage)
    else:
        device = torch.cuda.current_device()
        pretrained_dict = torch.load(pretrained_path, map_location=lambda storage, loc: storage.cuda(device))
    if "state_dict" in pretrained_dict.keys():
        pretrained_dict = remove_prefix(pretrained_dict['state_dict'], 'module.')
    else:
        pretrained_dict = remove_prefix(pretrained_dict, 'module.')
    check_keys(model, pretrained_dict)
    model.load_state_dict(pretrained_dict, strict=False)
    return model


if __name__ == '__main__':
    torch.set_grad_enabled(False)

    cfg = None
    if args.network == "mobile0.25":
        cfg = cfg_mnet
    elif args.network == "resnet50":
        cfg = cfg_re50
    # net and model
    net = RetinaFace(cfg=cfg, phase = 'test')
    net = load_model(net, args.trained_model, args.cpu)
    net.eval()
    print('Finished loading model!')
    print(net)
    cudnn.benchmark = True
    device = torch.device("cpu" if args.cpu else "cuda")
    net = net.to(device)

    # testing dataset
    testset_folder = args.dataset_folder
    testset_list = args.dataset_folder[:-7] + "wider_val.txt"

    with open(testset_list, 'r') as fr:
        test_dataset = fr.read().split()
    num_images = len(test_dataset)

    _t = {'forward_pass': Timer(), 'misc': Timer()}

    # testing begin
    for i, img_name in enumerate(test_dataset):
        image_path = testset_folder + img_name
        img_raw = cv2.imread(image_path, cv2.IMREAD_COLOR)
        img = np.float32(img_raw)

        # testing scale
        target_size = 1600
        max_size = 2150
        im_shape = img.shape
        im_size_min = np.min(im_shape[0:2])
        im_size_max = np.max(im_shape[0:2])
        resize = float(target_size) / float(im_size_min)
        # prevent bigger axis from being more than max_size:
        if np.round(resize * im_size_max) > max_size:
            resize = float(max_size) / float(im_size_max)
        if args.origin_size:
            resize = 1

        if resize != 1:
            img = cv2.resize(img, None, None, fx=resize, fy=resize, interpolation=cv2.INTER_LINEAR)
        im_height, im_width, _ = img.shape
        scale = torch.Tensor([img.shape[1], img.shape[0], img.shape[1], img.shape[0]])
        img -= (104, 117, 123)
        img = img.transpose(2, 0, 1)
        img = torch.from_numpy(img).unsqueeze(0)
        img = img.to(device)
        scale = scale.to(device)

        _t['forward_pass'].tic()
        loc, conf, landms = net(img)  # forward pass
        _t['forward_pass'].toc()
        _t['misc'].tic()
        priorbox = PriorBox(cfg, image_size=(im_height, im_width))
        priors = priorbox.forward()
        priors = priors.to(device)
        prior_data = priors.data
        boxes = decode(loc.data.squeeze(0), prior_data, cfg['variance'])
        boxes = boxes * scale / resize
        boxes = boxes.cpu().numpy()
        scores = conf.squeeze(0).data.cpu().numpy()[:, 1]
        landms = decode_landm(landms.data.squeeze(0), prior_data, cfg['variance'])
        scale1 = torch.Tensor([img.shape[3], img.shape[2], img.shape[3], img.shape[2],
                               img.shape[3], img.shape[2], img.shape[3], img.shape[2],
                               img.shape[3], img.shape[2]])
        scale1 = scale1.to(device)
        landms = landms * scale1 / resize
        landms = landms.cpu().numpy()

        # ignore low scores
        inds = np.where(scores > args.confidence_threshold)[0]
        boxes = boxes[inds]
        landms = landms[inds]
        scores = scores[inds]

        # keep top-K before NMS
        order = scores.argsort()[::-1]
        # order = scores.argsort()[::-1][:args.top_k]
        boxes = boxes[order]
        landms = landms[order]
        scores = scores[order]

        # do NMS
        dets = np.hstack((boxes, scores[:, np.newaxis])).astype(np.float32, copy=False)
        keep = py_cpu_nms(dets, args.nms_threshold)
        # keep = nms(dets, args.nms_threshold,force_cpu=args.cpu)
        dets = dets[keep, :]
        landms = landms[keep]

        # keep top-K faster NMS
        # dets = dets[:args.keep_top_k, :]
        # landms = landms[:args.keep_top_k, :]

        dets = np.concatenate((dets, landms), axis=1)
        _t['misc'].toc()

        # --------------------------------------------------------------------
        save_name = args.save_folder + img_name[:-4] + ".txt"
        dirname = os.path.dirname(save_name)
        if not os.path.isdir(dirname):
            os.makedirs(dirname)
        with open(save_name, "w") as fd:
            bboxs = dets
            file_name = os.path.basename(save_name)[:-4] + "\n"
            bboxs_num = str(len(bboxs)) + "\n"
            fd.write(file_name)
            fd.write(bboxs_num)
            for box in bboxs:
                x = int(box[0])
                y = int(box[1])
                w = int(box[2]) - int(box[0])
                h = int(box[3]) - int(box[1])
                confidence = str(box[4])
                line = str(x) + " " + str(y) + " " + str(w) + " " + str(h) + " " + confidence + " \n"
                fd.write(line)

        print('im_detect: {:d}/{:d} forward_pass_time: {:.4f}s misc: {:.4f}s'.format(i + 1, num_images, _t['forward_pass'].average_time, _t['misc'].average_time))

        # save image
        if args.save_image:
            for b in dets:
                if b[4] < args.vis_thres:
                    continue
                text = "{:.4f}".format(b[4])
                b = list(map(int, b))
                cv2.rectangle(img_raw, (b[0], b[1]), (b[2], b[3]), (0, 0, 255), 2)
                cx = b[0]
                cy = b[1] + 12
                cv2.putText(img_raw, text, (cx, cy),
                            cv2.FONT_HERSHEY_DUPLEX, 0.5, (255, 255, 255))

                # landms
                cv2.circle(img_raw, (b[5], b[6]), 1, (0, 0, 255), 4)
                cv2.circle(img_raw, (b[7], b[8]), 1, (0, 255, 255), 4)
                cv2.circle(img_raw, (b[9], b[10]), 1, (255, 0, 255), 4)
                cv2.circle(img_raw, (b[11], b[12]), 1, (0, 255, 0), 4)
                cv2.circle(img_raw, (b[13], b[14]), 1, (255, 0, 0), 4)
            # save image
            if not os.path.exists("./results/"):
                os.makedirs("./results/")
            name = "./results/" + str(i) + ".jpg"
            cv2.imwrite(name, img_raw)
# Out:
# Loading pretrained model from ./weights/Resnet50_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:456
# Finished loading model!
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (fpn): FPN(
#     (output1): Sequential(
#       (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (output2): Sequential(
#       (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (output3): Sequential(
#       (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (merge1): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (merge2): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#   )
#   (ssh1): SSH(
#     (conv3X3): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv5X5_1): Sequential(
#       (0): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (conv5X5_2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv7X7_2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (conv7x7_3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (ssh2): SSH(
#     (conv3X3): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv5X5_1): Sequential(
#       (0): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (conv5X5_2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv7X7_2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (conv7x7_3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (ssh3): SSH(
#     (conv3X3): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv5X5_1): Sequential(
#       (0): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (conv5X5_2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv7X7_2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0, inplace=True)
#     )
#     (conv7x7_3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (ClassHead): ModuleList(
#     (0-2): 3 x ClassHead(
#       (conv1x1): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (BboxHead): ModuleList(
#     (0-2): 3 x BboxHead(
#       (conv1x1): Conv2d(256, 8, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (LandmarkHead): ModuleList(
#     (0-2): 3 x LandmarkHead(
#       (conv1x1): Conv2d(256, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# im_detect: 1/3226 forward_pass_time: 0.0119s misc: 0.0316s
# im_detect: 2/3226 forward_pass_time: 0.0107s misc: 0.0344s
# im_detect: 3/3226 forward_pass_time: 0.0103s misc: 0.0350s
# im_detect: 4/3226 forward_pass_time: 0.0098s misc: 0.0374s
# im_detect: 5/3226 forward_pass_time: 0.0098s misc: 0.0458s
# im_detect: 6/3226 forward_pass_time: 0.0096s misc: 0.0439s
# im_detect: 7/3226 forward_pass_time: 0.0684s misc: 0.0485s
# im_detect: 8/3226 forward_pass_time: 0.1030s misc: 0.0454s
# im_detect: 9/3226 forward_pass_time: 0.1309s misc: 0.0435s
# im_detect: 10/3226 forward_pass_time: 0.1607s misc: 0.0457s
# im_detect: 11/3226 forward_pass_time: 0.1660s misc: 0.0454s
# im_detect: 12/3226 forward_pass_time: 0.1785s misc: 0.0446s
# im_detect: 13/3226 forward_pass_time: 0.1923s misc: 0.0435s
# im_detect: 14/3226 forward_pass_time: 0.1943s misc: 0.0429s
# im_detect: 15/3226 forward_pass_time: 0.1836s misc: 0.0450s
# im_detect: 16/3226 forward_pass_time: 0.1738s misc: 0.0442s
# im_detect: 17/3226 forward_pass_time: 0.1744s misc: 0.0433s
# im_detect: 18/3226 forward_pass_time: 0.1888s misc: 0.0451s
# im_detect: 19/3226 forward_pass_time: 0.1967s misc: 0.0450s
# im_detect: 20/3226 forward_pass_time: 0.2048s misc: 0.0452s
# im_detect: 21/3226 forward_pass_time: 0.2113s misc: 0.0452s
# im_detect: 22/3226 forward_pass_time: 0.2029s misc: 0.0446s
# im_detect: 23/3226 forward_pass_time: 0.1952s misc: 0.0442s
# im_detect: 24/3226 forward_pass_time: 0.1976s misc: 0.0435s
# im_detect: 25/3226 forward_pass_time: 0.2034s misc: 0.0432s
# im_detect: 26/3226 forward_pass_time: 0.1959s misc: 0.0426s
# im_detect: 27/3226 forward_pass_time: 0.1921s misc: 0.0422s
# im_detect: 28/3226 forward_pass_time: 0.1884s misc: 0.0420s
# im_detect: 29/3226 forward_pass_time: 0.1939s misc: 0.0431s
# im_detect: 30/3226 forward_pass_time: 0.1877s misc: 0.0428s
# im_detect: 31/3226 forward_pass_time: 0.1908s misc: 0.0425s
# im_detect: 32/3226 forward_pass_time: 0.1850s misc: 0.0421s
# im_detect: 33/3226 forward_pass_time: 0.1823s misc: 0.0419s
# im_detect: 34/3226 forward_pass_time: 0.1776s misc: 0.0417s
# im_detect: 35/3226 forward_pass_time: 0.1728s misc: 0.0415s
# im_detect: 36/3226 forward_pass_time: 0.1682s misc: 0.0414s
# im_detect: 37/3226 forward_pass_time: 0.1639s misc: 0.0413s
# im_detect: 38/3226 forward_pass_time: 0.1603s misc: 0.0411s
# im_detect: 39/3226 forward_pass_time: 0.1594s misc: 0.0419s
# im_detect: 40/3226 forward_pass_time: 0.1561s misc: 0.0420s
# im_detect: 41/3226 forward_pass_time: 0.1605s misc: 0.0417s
# im_detect: 42/3226 forward_pass_time: 0.1569s misc: 0.0425s
# im_detect: 43/3226 forward_pass_time: 0.1553s misc: 0.0424s
# im_detect: 44/3226 forward_pass_time: 0.1612s misc: 0.0431s
# im_detect: 45/3226 forward_pass_time: 0.1578s misc: 0.0429s
# im_detect: 46/3226 forward_pass_time: 0.1637s misc: 0.0437s
# im_detect: 47/3226 forward_pass_time: 0.1608s misc: 0.0434s
# im_detect: 48/3226 forward_pass_time: 0.1576s misc: 0.0431s
# im_detect: 49/3226 forward_pass_time: 0.1545s misc: 0.0430s
# im_detect: 50/3226 forward_pass_time: 0.1569s misc: 0.0428s
# im_detect: 51/3226 forward_pass_time: 0.1540s misc: 0.0426s
# im_detect: 52/3226 forward_pass_time: 0.1513s misc: 0.0424s
# im_detect: 53/3226 forward_pass_time: 0.1535s misc: 0.0422s
# im_detect: 54/3226 forward_pass_time: 0.1508s misc: 0.0420s
# im_detect: 55/3226 forward_pass_time: 0.1488s misc: 0.0426s
# im_detect: 56/3226 forward_pass_time: 0.1484s misc: 0.0432s
# im_detect: 57/3226 forward_pass_time: 0.1533s misc: 0.0438s
# im_detect: 58/3226 forward_pass_time: 0.1508s misc: 0.0443s
# im_detect: 59/3226 forward_pass_time: 0.1515s misc: 0.0442s
# im_detect: 60/3226 forward_pass_time: 0.1559s misc: 0.0446s
# im_detect: 61/3226 forward_pass_time: 0.1575s misc: 0.0443s
# im_detect: 62/3226 forward_pass_time: 0.1592s misc: 0.0441s
# im_detect: 63/3226 forward_pass_time: 0.1568s misc: 0.0446s
# im_detect: 64/3226 forward_pass_time: 0.1545s misc: 0.0445s
# im_detect: 65/3226 forward_pass_time: 0.1523s misc: 0.0444s
# im_detect: 66/3226 forward_pass_time: 0.1501s misc: 0.0442s
# im_detect: 67/3226 forward_pass_time: 0.1517s misc: 0.0447s
# im_detect: 68/3226 forward_pass_time: 0.1496s misc: 0.0446s
# im_detect: 69/3226 forward_pass_time: 0.1503s misc: 0.0445s
# im_detect: 70/3226 forward_pass_time: 0.1495s misc: 0.0443s
# im_detect: 71/3226 forward_pass_time: 0.1475s misc: 0.0441s
# im_detect: 72/3226 forward_pass_time: 0.1481s misc: 0.0439s
# im_detect: 73/3226 forward_pass_time: 0.1462s misc: 0.0443s
# im_detect: 74/3226 forward_pass_time: 0.1444s misc: 0.0442s
# im_detect: 75/3226 forward_pass_time: 0.1426s misc: 0.0441s
# im_detect: 76/3226 forward_pass_time: 0.1408s misc: 0.0441s
# im_detect: 77/3226 forward_pass_time: 0.1394s misc: 0.0440s
# im_detect: 78/3226 forward_pass_time: 0.1420s misc: 0.0439s
# im_detect: 79/3226 forward_pass_time: 0.1403s misc: 0.0438s
# im_detect: 80/3226 forward_pass_time: 0.1390s misc: 0.0442s
# im_detect: 81/3226 forward_pass_time: 0.1395s misc: 0.0440s
# im_detect: 82/3226 forward_pass_time: 0.1379s misc: 0.0444s
# im_detect: 83/3226 forward_pass_time: 0.1364s misc: 0.0443s
# im_detect: 84/3226 forward_pass_time: 0.1352s misc: 0.0446s
# im_detect: 85/3226 forward_pass_time: 0.1337s misc: 0.0445s
# im_detect: 86/3226 forward_pass_time: 0.1380s misc: 0.0453s
# im_detect: 87/3226 forward_pass_time: 0.1365s misc: 0.0452s
# im_detect: 88/3226 forward_pass_time: 0.1387s misc: 0.0454s
# im_detect: 89/3226 forward_pass_time: 0.1392s misc: 0.0452s
# im_detect: 90/3226 forward_pass_time: 0.1378s misc: 0.0452s
# im_detect: 91/3226 forward_pass_time: 0.1407s misc: 0.0454s
# im_detect: 92/3226 forward_pass_time: 0.1402s misc: 0.0452s
# im_detect: 93/3226 forward_pass_time: 0.1408s misc: 0.0451s
# im_detect: 94/3226 forward_pass_time: 0.1394s misc: 0.0450s
# im_detect: 95/3226 forward_pass_time: 0.1407s misc: 0.0449s
# im_detect: 96/3226 forward_pass_time: 0.1439s misc: 0.0453s
# im_detect: 97/3226 forward_pass_time: 0.1426s misc: 0.0451s
# im_detect: 98/3226 forward_pass_time: 0.1421s misc: 0.0450s
# im_detect: 99/3226 forward_pass_time: 0.1408s misc: 0.0450s
# im_detect: 100/3226 forward_pass_time: 0.1395s misc: 0.0449s
# im_detect: 101/3226 forward_pass_time: 0.1382s misc: 0.0448s
# im_detect: 102/3226 forward_pass_time: 0.1396s misc: 0.0447s
# im_detect: 103/3226 forward_pass_time: 0.1384s misc: 0.0446s
# im_detect: 104/3226 forward_pass_time: 0.1371s misc: 0.0445s
# im_detect: 105/3226 forward_pass_time: 0.1359s misc: 0.0444s
# im_detect: 106/3226 forward_pass_time: 0.1355s misc: 0.0443s
# im_detect: 107/3226 forward_pass_time: 0.1343s misc: 0.0444s
# im_detect: 108/3226 forward_pass_time: 0.1331s misc: 0.0443s
# im_detect: 109/3226 forward_pass_time: 0.1320s misc: 0.0443s
# im_detect: 110/3226 forward_pass_time: 0.1309s misc: 0.0441s
# im_detect: 111/3226 forward_pass_time: 0.1298s misc: 0.0441s
# im_detect: 112/3226 forward_pass_time: 0.1287s misc: 0.0440s
# im_detect: 113/3226 forward_pass_time: 0.1293s misc: 0.0439s
# im_detect: 114/3226 forward_pass_time: 0.1283s misc: 0.0439s
# im_detect: 115/3226 forward_pass_time: 0.1293s misc: 0.0441s
# im_detect: 116/3226 forward_pass_time: 0.1290s misc: 0.0440s
# im_detect: 117/3226 forward_pass_time: 0.1301s misc: 0.0443s
# im_detect: 118/3226 forward_pass_time: 0.1298s misc: 0.0442s
# im_detect: 119/3226 forward_pass_time: 0.1288s misc: 0.0441s
# im_detect: 120/3226 forward_pass_time: 0.1278s misc: 0.0440s
# im_detect: 121/3226 forward_pass_time: 0.1268s misc: 0.0439s
# im_detect: 122/3226 forward_pass_time: 0.1264s misc: 0.0438s
# im_detect: 123/3226 forward_pass_time: 0.1256s misc: 0.0439s
# im_detect: 124/3226 forward_pass_time: 0.1247s misc: 0.0439s
# im_detect: 125/3226 forward_pass_time: 0.1239s misc: 0.0438s
# im_detect: 126/3226 forward_pass_time: 0.1236s misc: 0.0436s
# im_detect: 127/3226 forward_pass_time: 0.1227s misc: 0.0436s
# im_detect: 128/3226 forward_pass_time: 0.1218s misc: 0.0436s
# im_detect: 129/3226 forward_pass_time: 0.1210s misc: 0.0435s
# im_detect: 130/3226 forward_pass_time: 0.1208s misc: 0.0435s
# im_detect: 131/3226 forward_pass_time: 0.1200s misc: 0.0435s
# im_detect: 132/3226 forward_pass_time: 0.1192s misc: 0.0434s
# im_detect: 133/3226 forward_pass_time: 0.1184s misc: 0.0436s
# im_detect: 134/3226 forward_pass_time: 0.1188s misc: 0.0436s
# im_detect: 135/3226 forward_pass_time: 0.1180s misc: 0.0435s
# im_detect: 136/3226 forward_pass_time: 0.1173s misc: 0.0434s
# im_detect: 137/3226 forward_pass_time: 0.1165s misc: 0.0434s
# im_detect: 138/3226 forward_pass_time: 0.1157s misc: 0.0433s
# im_detect: 139/3226 forward_pass_time: 0.1156s misc: 0.0433s
# im_detect: 140/3226 forward_pass_time: 0.1148s misc: 0.0432s
# im_detect: 141/3226 forward_pass_time: 0.1142s misc: 0.0432s
# im_detect: 142/3226 forward_pass_time: 0.1156s misc: 0.0431s
# im_detect: 143/3226 forward_pass_time: 0.1149s misc: 0.0431s
# im_detect: 144/3226 forward_pass_time: 0.1155s misc: 0.0430s
# im_detect: 145/3226 forward_pass_time: 0.1148s misc: 0.0430s
# im_detect: 146/3226 forward_pass_time: 0.1141s misc: 0.0432s
# im_detect: 147/3226 forward_pass_time: 0.1134s misc: 0.0434s
# im_detect: 148/3226 forward_pass_time: 0.1132s misc: 0.0433s
# im_detect: 149/3226 forward_pass_time: 0.1125s misc: 0.0432s
# im_detect: 150/3226 forward_pass_time: 0.1118s misc: 0.0432s
# im_detect: 151/3226 forward_pass_time: 0.1111s misc: 0.0432s
# im_detect: 152/3226 forward_pass_time: 0.1105s misc: 0.0431s
# im_detect: 153/3226 forward_pass_time: 0.1114s misc: 0.0430s
# im_detect: 154/3226 forward_pass_time: 0.1107s misc: 0.0430s
# im_detect: 155/3226 forward_pass_time: 0.1119s misc: 0.0428s
# im_detect: 156/3226 forward_pass_time: 0.1114s misc: 0.0428s
# im_detect: 157/3226 forward_pass_time: 0.1109s misc: 0.0428s
# im_detect: 158/3226 forward_pass_time: 0.1102s misc: 0.0428s
# im_detect: 159/3226 forward_pass_time: 0.1097s misc: 0.0427s
# im_detect: 160/3226 forward_pass_time: 0.1108s misc: 0.0427s
# im_detect: 161/3226 forward_pass_time: 0.1101s misc: 0.0427s
# im_detect: 162/3226 forward_pass_time: 0.1107s misc: 0.0427s
# im_detect: 163/3226 forward_pass_time: 0.1101s misc: 0.0427s
# im_detect: 164/3226 forward_pass_time: 0.1119s misc: 0.0429s
# im_detect: 165/3226 forward_pass_time: 0.1113s misc: 0.0428s
# im_detect: 166/3226 forward_pass_time: 0.1107s misc: 0.0428s
# im_detect: 167/3226 forward_pass_time: 0.1101s misc: 0.0428s
# im_detect: 168/3226 forward_pass_time: 0.1095s misc: 0.0428s
# im_detect: 169/3226 forward_pass_time: 0.1091s misc: 0.0427s
# im_detect: 170/3226 forward_pass_time: 0.1085s misc: 0.0427s
# im_detect: 171/3226 forward_pass_time: 0.1090s misc: 0.0430s
# im_detect: 172/3226 forward_pass_time: 0.1084s misc: 0.0430s
# im_detect: 173/3226 forward_pass_time: 0.1080s misc: 0.0429s
# im_detect: 174/3226 forward_pass_time: 0.1075s misc: 0.0429s
# im_detect: 175/3226 forward_pass_time: 0.1070s misc: 0.0428s
# im_detect: 176/3226 forward_pass_time: 0.1064s misc: 0.0428s
# im_detect: 177/3226 forward_pass_time: 0.1059s misc: 0.0427s
# im_detect: 178/3226 forward_pass_time: 0.1054s misc: 0.0427s
# im_detect: 179/3226 forward_pass_time: 0.1048s misc: 0.0426s
# im_detect: 180/3226 forward_pass_time: 0.1043s misc: 0.0426s
# im_detect: 181/3226 forward_pass_time: 0.1038s misc: 0.0428s
# im_detect: 182/3226 forward_pass_time: 0.1033s misc: 0.0428s
# im_detect: 183/3226 forward_pass_time: 0.1029s misc: 0.0429s
# im_detect: 184/3226 forward_pass_time: 0.1024s misc: 0.0428s
# im_detect: 185/3226 forward_pass_time: 0.1019s misc: 0.0428s
# im_detect: 186/3226 forward_pass_time: 0.1014s misc: 0.0430s
# im_detect: 187/3226 forward_pass_time: 0.1010s misc: 0.0429s
# im_detect: 188/3226 forward_pass_time: 0.1006s misc: 0.0429s
# im_detect: 189/3226 forward_pass_time: 0.1015s misc: 0.0429s
# im_detect: 190/3226 forward_pass_time: 0.1011s misc: 0.0429s
# im_detect: 191/3226 forward_pass_time: 0.1006s misc: 0.0428s
# im_detect: 192/3226 forward_pass_time: 0.1001s misc: 0.0428s
# im_detect: 193/3226 forward_pass_time: 0.0997s misc: 0.0428s
# im_detect: 194/3226 forward_pass_time: 0.0996s misc: 0.0428s
# im_detect: 195/3226 forward_pass_time: 0.0992s misc: 0.0427s
# im_detect: 196/3226 forward_pass_time: 0.0987s misc: 0.0427s
# im_detect: 197/3226 forward_pass_time: 0.0983s misc: 0.0427s
# im_detect: 198/3226 forward_pass_time: 0.0978s misc: 0.0427s
# im_detect: 199/3226 forward_pass_time: 0.0975s misc: 0.0426s
# im_detect: 200/3226 forward_pass_time: 0.0971s misc: 0.0426s
# im_detect: 201/3226 forward_pass_time: 0.0966s misc: 0.0425s
# im_detect: 202/3226 forward_pass_time: 0.0962s misc: 0.0425s
# im_detect: 203/3226 forward_pass_time: 0.0959s misc: 0.0425s
# im_detect: 204/3226 forward_pass_time: 0.0955s misc: 0.0425s
# im_detect: 205/3226 forward_pass_time: 0.0952s misc: 0.0426s
# im_detect: 206/3226 forward_pass_time: 0.0948s misc: 0.0426s
# im_detect: 207/3226 forward_pass_time: 0.0944s misc: 0.0425s
# im_detect: 208/3226 forward_pass_time: 0.0941s misc: 0.0425s
# im_detect: 209/3226 forward_pass_time: 0.0937s misc: 0.0425s
# im_detect: 210/3226 forward_pass_time: 0.0950s misc: 0.0426s
# im_detect: 211/3226 forward_pass_time: 0.0946s misc: 0.0425s
# im_detect: 212/3226 forward_pass_time: 0.0942s misc: 0.0425s
# im_detect: 213/3226 forward_pass_time: 0.0942s misc: 0.0425s
# im_detect: 214/3226 forward_pass_time: 0.0939s misc: 0.0424s
# im_detect: 215/3226 forward_pass_time: 0.0935s misc: 0.0424s
# im_detect: 216/3226 forward_pass_time: 0.0936s misc: 0.0425s
# im_detect: 217/3226 forward_pass_time: 0.0932s misc: 0.0425s
# im_detect: 218/3226 forward_pass_time: 0.0933s misc: 0.0425s
# im_detect: 219/3226 forward_pass_time: 0.0929s misc: 0.0424s
# im_detect: 220/3226 forward_pass_time: 0.0925s misc: 0.0424s
# im_detect: 221/3226 forward_pass_time: 0.0922s misc: 0.0425s
# im_detect: 222/3226 forward_pass_time: 0.0918s misc: 0.0425s
# im_detect: 223/3226 forward_pass_time: 0.0915s misc: 0.0424s
# im_detect: 224/3226 forward_pass_time: 0.0913s misc: 0.0424s
# im_detect: 225/3226 forward_pass_time: 0.0909s misc: 0.0425s
# im_detect: 226/3226 forward_pass_time: 0.0905s misc: 0.0426s
# im_detect: 227/3226 forward_pass_time: 0.0902s misc: 0.0426s
# im_detect: 228/3226 forward_pass_time: 0.0906s misc: 0.0425s
# im_detect: 229/3226 forward_pass_time: 0.0910s misc: 0.0424s
# im_detect: 230/3226 forward_pass_time: 0.0906s misc: 0.0424s
# im_detect: 231/3226 forward_pass_time: 0.0903s misc: 0.0424s
# im_detect: 232/3226 forward_pass_time: 0.0899s misc: 0.0423s
# im_detect: 233/3226 forward_pass_time: 0.0904s misc: 0.0423s
# im_detect: 234/3226 forward_pass_time: 0.0900s misc: 0.0424s
# im_detect: 235/3226 forward_pass_time: 0.0901s misc: 0.0425s
# im_detect: 236/3226 forward_pass_time: 0.0897s misc: 0.0424s
# im_detect: 237/3226 forward_pass_time: 0.0897s misc: 0.0424s
# im_detect: 238/3226 forward_pass_time: 0.0894s misc: 0.0423s
# im_detect: 239/3226 forward_pass_time: 0.0909s misc: 0.0424s
# im_detect: 240/3226 forward_pass_time: 0.0906s misc: 0.0425s
# im_detect: 241/3226 forward_pass_time: 0.0902s misc: 0.0426s
# im_detect: 242/3226 forward_pass_time: 0.0911s misc: 0.0425s
# im_detect: 243/3226 forward_pass_time: 0.0908s misc: 0.0424s
# im_detect: 244/3226 forward_pass_time: 0.0918s misc: 0.0425s
# im_detect: 245/3226 forward_pass_time: 0.0916s misc: 0.0425s
# im_detect: 246/3226 forward_pass_time: 0.0913s misc: 0.0425s
# im_detect: 247/3226 forward_pass_time: 0.0910s misc: 0.0427s
# im_detect: 248/3226 forward_pass_time: 0.0908s misc: 0.0427s
# im_detect: 249/3226 forward_pass_time: 0.0904s misc: 0.0426s
# im_detect: 250/3226 forward_pass_time: 0.0901s misc: 0.0426s
# im_detect: 251/3226 forward_pass_time: 0.0899s misc: 0.0428s
# im_detect: 252/3226 forward_pass_time: 0.0896s misc: 0.0428s
# im_detect: 253/3226 forward_pass_time: 0.0913s misc: 0.0431s
# im_detect: 254/3226 forward_pass_time: 0.0911s misc: 0.0431s
# im_detect: 255/3226 forward_pass_time: 0.0908s misc: 0.0431s
# im_detect: 256/3226 forward_pass_time: 0.0905s misc: 0.0431s
# im_detect: 257/3226 forward_pass_time: 0.0902s misc: 0.0430s
# im_detect: 258/3226 forward_pass_time: 0.0908s misc: 0.0430s
# im_detect: 259/3226 forward_pass_time: 0.0905s misc: 0.0431s
# im_detect: 260/3226 forward_pass_time: 0.0913s misc: 0.0431s
# im_detect: 261/3226 forward_pass_time: 0.0910s misc: 0.0430s
# im_detect: 262/3226 forward_pass_time: 0.0907s misc: 0.0430s
# im_detect: 263/3226 forward_pass_time: 0.0904s misc: 0.0430s
# im_detect: 264/3226 forward_pass_time: 0.0902s misc: 0.0430s
# im_detect: 265/3226 forward_pass_time: 0.0899s misc: 0.0429s
# im_detect: 266/3226 forward_pass_time: 0.0896s misc: 0.0429s
# im_detect: 267/3226 forward_pass_time: 0.0896s misc: 0.0428s
# im_detect: 268/3226 forward_pass_time: 0.0893s misc: 0.0428s
# im_detect: 269/3226 forward_pass_time: 0.0893s misc: 0.0428s
# im_detect: 270/3226 forward_pass_time: 0.0891s misc: 0.0428s
# im_detect: 271/3226 forward_pass_time: 0.0888s misc: 0.0427s
# im_detect: 272/3226 forward_pass_time: 0.0885s misc: 0.0427s
# im_detect: 273/3226 forward_pass_time: 0.0885s misc: 0.0427s
# im_detect: 274/3226 forward_pass_time: 0.0882s misc: 0.0428s
# im_detect: 275/3226 forward_pass_time: 0.0880s misc: 0.0427s
# im_detect: 276/3226 forward_pass_time: 0.0878s misc: 0.0427s
# im_detect: 277/3226 forward_pass_time: 0.0882s misc: 0.0428s
# im_detect: 278/3226 forward_pass_time: 0.0879s misc: 0.0428s
# im_detect: 279/3226 forward_pass_time: 0.0877s misc: 0.0428s
# im_detect: 280/3226 forward_pass_time: 0.0875s misc: 0.0428s
# im_detect: 281/3226 forward_pass_time: 0.0872s misc: 0.0428s
# im_detect: 282/3226 forward_pass_time: 0.0869s misc: 0.0428s
# im_detect: 283/3226 forward_pass_time: 0.0867s misc: 0.0428s
# im_detect: 284/3226 forward_pass_time: 0.0865s misc: 0.0427s
# im_detect: 285/3226 forward_pass_time: 0.0873s misc: 0.0428s
# im_detect: 286/3226 forward_pass_time: 0.0871s misc: 0.0428s
# im_detect: 287/3226 forward_pass_time: 0.0868s misc: 0.0427s
# im_detect: 288/3226 forward_pass_time: 0.0874s misc: 0.0428s
# im_detect: 289/3226 forward_pass_time: 0.0884s misc: 0.0430s
# im_detect: 290/3226 forward_pass_time: 0.0881s misc: 0.0429s
# im_detect: 291/3226 forward_pass_time: 0.0879s misc: 0.0429s
# im_detect: 292/3226 forward_pass_time: 0.0876s misc: 0.0429s
# im_detect: 293/3226 forward_pass_time: 0.0873s misc: 0.0428s
# im_detect: 294/3226 forward_pass_time: 0.0874s misc: 0.0428s
# im_detect: 295/3226 forward_pass_time: 0.0871s misc: 0.0428s
# im_detect: 296/3226 forward_pass_time: 0.0869s misc: 0.0429s
# im_detect: 297/3226 forward_pass_time: 0.0874s misc: 0.0429s
# im_detect: 298/3226 forward_pass_time: 0.0881s misc: 0.0429s
# im_detect: 299/3226 forward_pass_time: 0.0878s misc: 0.0430s
# im_detect: 300/3226 forward_pass_time: 0.0876s misc: 0.0431s
# im_detect: 301/3226 forward_pass_time: 0.0873s misc: 0.0431s
# im_detect: 302/3226 forward_pass_time: 0.0871s misc: 0.0431s
# im_detect: 303/3226 forward_pass_time: 0.0868s misc: 0.0430s
# im_detect: 304/3226 forward_pass_time: 0.0866s misc: 0.0430s
# im_detect: 305/3226 forward_pass_time: 0.0863s misc: 0.0430s
# im_detect: 306/3226 forward_pass_time: 0.0861s misc: 0.0430s
# im_detect: 307/3226 forward_pass_time: 0.0859s misc: 0.0429s
# im_detect: 308/3226 forward_pass_time: 0.0856s misc: 0.0429s
# im_detect: 309/3226 forward_pass_time: 0.0854s misc: 0.0429s
# im_detect: 310/3226 forward_pass_time: 0.0851s misc: 0.0428s
# im_detect: 311/3226 forward_pass_time: 0.0849s misc: 0.0428s
# im_detect: 312/3226 forward_pass_time: 0.0847s misc: 0.0428s
# im_detect: 313/3226 forward_pass_time: 0.0846s misc: 0.0427s
# im_detect: 314/3226 forward_pass_time: 0.0843s misc: 0.0427s
# im_detect: 315/3226 forward_pass_time: 0.0841s misc: 0.0427s
# im_detect: 316/3226 forward_pass_time: 0.0839s misc: 0.0427s
# im_detect: 317/3226 forward_pass_time: 0.0837s misc: 0.0426s
# im_detect: 318/3226 forward_pass_time: 0.0835s misc: 0.0426s
# im_detect: 319/3226 forward_pass_time: 0.0833s misc: 0.0426s
# im_detect: 320/3226 forward_pass_time: 0.0830s misc: 0.0426s
# im_detect: 321/3226 forward_pass_time: 0.0831s misc: 0.0426s
# im_detect: 322/3226 forward_pass_time: 0.0829s misc: 0.0425s
# im_detect: 323/3226 forward_pass_time: 0.0837s misc: 0.0425s
# im_detect: 324/3226 forward_pass_time: 0.0837s misc: 0.0425s
# im_detect: 325/3226 forward_pass_time: 0.0835s misc: 0.0425s
# im_detect: 326/3226 forward_pass_time: 0.0835s misc: 0.0424s
# im_detect: 327/3226 forward_pass_time: 0.0833s misc: 0.0424s
# im_detect: 328/3226 forward_pass_time: 0.0836s misc: 0.0424s
# im_detect: 329/3226 forward_pass_time: 0.0834s misc: 0.0424s
# im_detect: 330/3226 forward_pass_time: 0.0832s misc: 0.0424s
# im_detect: 331/3226 forward_pass_time: 0.0830s misc: 0.0424s
# im_detect: 332/3226 forward_pass_time: 0.0828s misc: 0.0424s
# im_detect: 333/3226 forward_pass_time: 0.0825s misc: 0.0424s
# im_detect: 334/3226 forward_pass_time: 0.0823s misc: 0.0424s
# im_detect: 335/3226 forward_pass_time: 0.0822s misc: 0.0424s
# im_detect: 336/3226 forward_pass_time: 0.0820s misc: 0.0423s
# im_detect: 337/3226 forward_pass_time: 0.0818s misc: 0.0423s
# im_detect: 338/3226 forward_pass_time: 0.0816s misc: 0.0423s
# im_detect: 339/3226 forward_pass_time: 0.0825s misc: 0.0423s
# im_detect: 340/3226 forward_pass_time: 0.0823s misc: 0.0423s
# im_detect: 341/3226 forward_pass_time: 0.0821s misc: 0.0423s
# im_detect: 342/3226 forward_pass_time: 0.0819s misc: 0.0422s
# im_detect: 343/3226 forward_pass_time: 0.0824s misc: 0.0423s
# im_detect: 344/3226 forward_pass_time: 0.0822s misc: 0.0423s
# im_detect: 345/3226 forward_pass_time: 0.0820s misc: 0.0423s
# im_detect: 346/3226 forward_pass_time: 0.0818s misc: 0.0422s
# im_detect: 347/3226 forward_pass_time: 0.0816s misc: 0.0422s
# im_detect: 348/3226 forward_pass_time: 0.0815s misc: 0.0422s
# im_detect: 349/3226 forward_pass_time: 0.0813s misc: 0.0422s
# im_detect: 350/3226 forward_pass_time: 0.0811s misc: 0.0421s
# im_detect: 351/3226 forward_pass_time: 0.0809s misc: 0.0421s
# im_detect: 352/3226 forward_pass_time: 0.0807s misc: 0.0421s
# im_detect: 353/3226 forward_pass_time: 0.0805s misc: 0.0421s
# im_detect: 354/3226 forward_pass_time: 0.0811s misc: 0.0421s
# im_detect: 355/3226 forward_pass_time: 0.0810s misc: 0.0420s
# im_detect: 356/3226 forward_pass_time: 0.0808s misc: 0.0420s
# im_detect: 357/3226 forward_pass_time: 0.0806s misc: 0.0420s
# im_detect: 358/3226 forward_pass_time: 0.0804s misc: 0.0420s
# im_detect: 359/3226 forward_pass_time: 0.0812s misc: 0.0420s
# im_detect: 360/3226 forward_pass_time: 0.0810s misc: 0.0420s
# im_detect: 361/3226 forward_pass_time: 0.0808s misc: 0.0419s
# im_detect: 362/3226 forward_pass_time: 0.0809s misc: 0.0419s
# im_detect: 363/3226 forward_pass_time: 0.0807s misc: 0.0419s
# im_detect: 364/3226 forward_pass_time: 0.0805s misc: 0.0419s
# im_detect: 365/3226 forward_pass_time: 0.0803s misc: 0.0419s
# im_detect: 366/3226 forward_pass_time: 0.0801s misc: 0.0419s
# im_detect: 367/3226 forward_pass_time: 0.0800s misc: 0.0418s
# im_detect: 368/3226 forward_pass_time: 0.0798s misc: 0.0418s
# im_detect: 369/3226 forward_pass_time: 0.0796s misc: 0.0418s
# im_detect: 370/3226 forward_pass_time: 0.0795s misc: 0.0418s
# im_detect: 371/3226 forward_pass_time: 0.0793s misc: 0.0418s
# im_detect: 372/3226 forward_pass_time: 0.0791s misc: 0.0417s
# im_detect: 373/3226 forward_pass_time: 0.0789s misc: 0.0417s
# im_detect: 374/3226 forward_pass_time: 0.0788s misc: 0.0417s
# im_detect: 375/3226 forward_pass_time: 0.0793s misc: 0.0417s
# im_detect: 376/3226 forward_pass_time: 0.0792s misc: 0.0416s
# im_detect: 377/3226 forward_pass_time: 0.0790s misc: 0.0416s
# im_detect: 378/3226 forward_pass_time: 0.0789s misc: 0.0416s
# im_detect: 379/3226 forward_pass_time: 0.0787s misc: 0.0416s
# im_detect: 380/3226 forward_pass_time: 0.0786s misc: 0.0416s
# im_detect: 381/3226 forward_pass_time: 0.0784s misc: 0.0416s
# im_detect: 382/3226 forward_pass_time: 0.0783s misc: 0.0416s
# im_detect: 383/3226 forward_pass_time: 0.0781s misc: 0.0416s
# im_detect: 384/3226 forward_pass_time: 0.0780s misc: 0.0416s
# im_detect: 385/3226 forward_pass_time: 0.0778s misc: 0.0416s
# im_detect: 386/3226 forward_pass_time: 0.0776s misc: 0.0415s
# im_detect: 387/3226 forward_pass_time: 0.0775s misc: 0.0415s
# im_detect: 388/3226 forward_pass_time: 0.0774s misc: 0.0415s
# im_detect: 389/3226 forward_pass_time: 0.0783s misc: 0.0416s
# im_detect: 390/3226 forward_pass_time: 0.0781s misc: 0.0416s
# im_detect: 391/3226 forward_pass_time: 0.0779s misc: 0.0416s
# im_detect: 392/3226 forward_pass_time: 0.0785s misc: 0.0415s
# im_detect: 393/3226 forward_pass_time: 0.0783s misc: 0.0415s
# im_detect: 394/3226 forward_pass_time: 0.0782s misc: 0.0415s
# im_detect: 395/3226 forward_pass_time: 0.0780s misc: 0.0415s
# im_detect: 396/3226 forward_pass_time: 0.0779s misc: 0.0415s
# im_detect: 397/3226 forward_pass_time: 0.0778s misc: 0.0415s
# im_detect: 398/3226 forward_pass_time: 0.0776s misc: 0.0416s
# im_detect: 399/3226 forward_pass_time: 0.0775s misc: 0.0415s
# im_detect: 400/3226 forward_pass_time: 0.0773s misc: 0.0415s
# im_detect: 401/3226 forward_pass_time: 0.0775s misc: 0.0415s
# im_detect: 402/3226 forward_pass_time: 0.0774s misc: 0.0415s
# im_detect: 403/3226 forward_pass_time: 0.0772s misc: 0.0415s
# im_detect: 404/3226 forward_pass_time: 0.0771s misc: 0.0415s
# im_detect: 405/3226 forward_pass_time: 0.0769s misc: 0.0414s
# im_detect: 406/3226 forward_pass_time: 0.0768s misc: 0.0414s
# im_detect: 407/3226 forward_pass_time: 0.0775s misc: 0.0414s
# im_detect: 408/3226 forward_pass_time: 0.0773s misc: 0.0414s
# im_detect: 409/3226 forward_pass_time: 0.0780s misc: 0.0415s
# im_detect: 410/3226 forward_pass_time: 0.0779s misc: 0.0414s
# im_detect: 411/3226 forward_pass_time: 0.0777s misc: 0.0414s
# im_detect: 412/3226 forward_pass_time: 0.0776s misc: 0.0414s
# im_detect: 413/3226 forward_pass_time: 0.0774s misc: 0.0414s
# im_detect: 414/3226 forward_pass_time: 0.0773s misc: 0.0415s
# im_detect: 415/3226 forward_pass_time: 0.0776s misc: 0.0415s
# im_detect: 416/3226 forward_pass_time: 0.0777s misc: 0.0416s
# im_detect: 417/3226 forward_pass_time: 0.0776s misc: 0.0415s
# im_detect: 418/3226 forward_pass_time: 0.0774s misc: 0.0415s
# im_detect: 419/3226 forward_pass_time: 0.0773s misc: 0.0415s
# im_detect: 420/3226 forward_pass_time: 0.0771s misc: 0.0415s
# im_detect: 421/3226 forward_pass_time: 0.0772s misc: 0.0415s
# im_detect: 422/3226 forward_pass_time: 0.0771s misc: 0.0415s
# im_detect: 423/3226 forward_pass_time: 0.0769s misc: 0.0415s
# im_detect: 424/3226 forward_pass_time: 0.0768s misc: 0.0415s
# im_detect: 425/3226 forward_pass_time: 0.0766s misc: 0.0415s
# im_detect: 426/3226 forward_pass_time: 0.0773s misc: 0.0416s
# im_detect: 427/3226 forward_pass_time: 0.0771s misc: 0.0416s
# im_detect: 428/3226 forward_pass_time: 0.0770s misc: 0.0415s
# im_detect: 429/3226 forward_pass_time: 0.0771s misc: 0.0416s
# im_detect: 430/3226 forward_pass_time: 0.0771s misc: 0.0417s
# im_detect: 431/3226 forward_pass_time: 0.0769s misc: 0.0417s
# im_detect: 432/3226 forward_pass_time: 0.0768s misc: 0.0417s
# im_detect: 433/3226 forward_pass_time: 0.0767s misc: 0.0418s
# im_detect: 434/3226 forward_pass_time: 0.0765s misc: 0.0418s
# im_detect: 435/3226 forward_pass_time: 0.0764s misc: 0.0417s
# im_detect: 436/3226 forward_pass_time: 0.0765s misc: 0.0417s
# im_detect: 437/3226 forward_pass_time: 0.0763s misc: 0.0417s
# im_detect: 438/3226 forward_pass_time: 0.0767s misc: 0.0417s
# im_detect: 439/3226 forward_pass_time: 0.0766s misc: 0.0417s
# im_detect: 440/3226 forward_pass_time: 0.0764s misc: 0.0417s
# im_detect: 441/3226 forward_pass_time: 0.0763s misc: 0.0417s
# im_detect: 442/3226 forward_pass_time: 0.0762s misc: 0.0417s
# im_detect: 443/3226 forward_pass_time: 0.0762s misc: 0.0417s
# im_detect: 444/3226 forward_pass_time: 0.0761s misc: 0.0416s
# im_detect: 445/3226 forward_pass_time: 0.0760s misc: 0.0416s
# im_detect: 446/3226 forward_pass_time: 0.0765s misc: 0.0415s
# im_detect: 447/3226 forward_pass_time: 0.0765s misc: 0.0415s
# im_detect: 448/3226 forward_pass_time: 0.0764s misc: 0.0415s
# im_detect: 449/3226 forward_pass_time: 0.0762s misc: 0.0415s
# im_detect: 450/3226 forward_pass_time: 0.0761s misc: 0.0415s
# im_detect: 451/3226 forward_pass_time: 0.0763s misc: 0.0414s
# im_detect: 452/3226 forward_pass_time: 0.0762s misc: 0.0414s
# im_detect: 453/3226 forward_pass_time: 0.0760s misc: 0.0414s
# im_detect: 454/3226 forward_pass_time: 0.0759s misc: 0.0414s
# im_detect: 455/3226 forward_pass_time: 0.0759s misc: 0.0413s
# im_detect: 456/3226 forward_pass_time: 0.0758s misc: 0.0413s
# im_detect: 457/3226 forward_pass_time: 0.0757s misc: 0.0413s
# im_detect: 458/3226 forward_pass_time: 0.0755s misc: 0.0413s
# im_detect: 459/3226 forward_pass_time: 0.0758s misc: 0.0413s
# im_detect: 460/3226 forward_pass_time: 0.0760s misc: 0.0413s
# im_detect: 461/3226 forward_pass_time: 0.0759s misc: 0.0412s
# im_detect: 462/3226 forward_pass_time: 0.0758s misc: 0.0413s
# im_detect: 463/3226 forward_pass_time: 0.0756s misc: 0.0413s
# im_detect: 464/3226 forward_pass_time: 0.0755s misc: 0.0413s
# im_detect: 465/3226 forward_pass_time: 0.0754s misc: 0.0413s
# im_detect: 466/3226 forward_pass_time: 0.0754s misc: 0.0413s
# im_detect: 467/3226 forward_pass_time: 0.0762s misc: 0.0414s
# im_detect: 468/3226 forward_pass_time: 0.0761s misc: 0.0414s
# im_detect: 469/3226 forward_pass_time: 0.0760s misc: 0.0413s
# im_detect: 470/3226 forward_pass_time: 0.0759s misc: 0.0413s
# im_detect: 471/3226 forward_pass_time: 0.0757s misc: 0.0414s
# im_detect: 472/3226 forward_pass_time: 0.0756s misc: 0.0413s
# im_detect: 473/3226 forward_pass_time: 0.0755s misc: 0.0413s
# im_detect: 474/3226 forward_pass_time: 0.0754s misc: 0.0413s
# im_detect: 475/3226 forward_pass_time: 0.0753s misc: 0.0413s
# im_detect: 476/3226 forward_pass_time: 0.0753s misc: 0.0413s
# im_detect: 477/3226 forward_pass_time: 0.0752s misc: 0.0412s
# im_detect: 478/3226 forward_pass_time: 0.0751s misc: 0.0412s
# im_detect: 479/3226 forward_pass_time: 0.0757s misc: 0.0413s
# im_detect: 480/3226 forward_pass_time: 0.0756s misc: 0.0413s
# im_detect: 481/3226 forward_pass_time: 0.0754s misc: 0.0413s
# im_detect: 482/3226 forward_pass_time: 0.0761s misc: 0.0414s
# im_detect: 483/3226 forward_pass_time: 0.0760s misc: 0.0414s
# im_detect: 484/3226 forward_pass_time: 0.0759s misc: 0.0413s
# im_detect: 485/3226 forward_pass_time: 0.0758s misc: 0.0414s
# im_detect: 486/3226 forward_pass_time: 0.0759s misc: 0.0414s
# im_detect: 487/3226 forward_pass_time: 0.0758s misc: 0.0414s
# im_detect: 488/3226 forward_pass_time: 0.0765s misc: 0.0415s
# im_detect: 489/3226 forward_pass_time: 0.0764s misc: 0.0414s
# im_detect: 490/3226 forward_pass_time: 0.0763s misc: 0.0414s
# im_detect: 491/3226 forward_pass_time: 0.0763s misc: 0.0414s
# im_detect: 492/3226 forward_pass_time: 0.0763s misc: 0.0414s
# im_detect: 493/3226 forward_pass_time: 0.0761s misc: 0.0415s
# im_detect: 494/3226 forward_pass_time: 0.0761s misc: 0.0415s
# im_detect: 495/3226 forward_pass_time: 0.0760s misc: 0.0415s
# im_detect: 496/3226 forward_pass_time: 0.0759s misc: 0.0415s
# im_detect: 497/3226 forward_pass_time: 0.0757s misc: 0.0415s
# im_detect: 498/3226 forward_pass_time: 0.0758s misc: 0.0415s
# im_detect: 499/3226 forward_pass_time: 0.0761s misc: 0.0415s
# im_detect: 500/3226 forward_pass_time: 0.0767s misc: 0.0415s
# im_detect: 501/3226 forward_pass_time: 0.0766s misc: 0.0416s
# im_detect: 502/3226 forward_pass_time: 0.0765s misc: 0.0416s
# im_detect: 503/3226 forward_pass_time: 0.0764s misc: 0.0416s
# im_detect: 504/3226 forward_pass_time: 0.0768s misc: 0.0416s
# im_detect: 505/3226 forward_pass_time: 0.0767s misc: 0.0416s
# im_detect: 506/3226 forward_pass_time: 0.0767s misc: 0.0416s
# im_detect: 507/3226 forward_pass_time: 0.0766s misc: 0.0416s
# im_detect: 508/3226 forward_pass_time: 0.0765s misc: 0.0415s
# im_detect: 509/3226 forward_pass_time: 0.0764s misc: 0.0416s
# im_detect: 510/3226 forward_pass_time: 0.0762s misc: 0.0415s
# im_detect: 511/3226 forward_pass_time: 0.0761s misc: 0.0416s
# im_detect: 512/3226 forward_pass_time: 0.0760s misc: 0.0417s
# im_detect: 513/3226 forward_pass_time: 0.0759s misc: 0.0417s
# im_detect: 514/3226 forward_pass_time: 0.0761s misc: 0.0417s
# im_detect: 515/3226 forward_pass_time: 0.0760s misc: 0.0417s
# ...
# im_detect: 2969/3226 forward_pass_time: 0.0492s misc: 0.0432s
# im_detect: 2970/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2971/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2972/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2973/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2974/3226 forward_pass_time: 0.0492s misc: 0.0432s
# im_detect: 2975/3226 forward_pass_time: 0.0492s misc: 0.0432s
# im_detect: 2976/3226 forward_pass_time: 0.0492s misc: 0.0432s
# im_detect: 2977/3226 forward_pass_time: 0.0492s misc: 0.0432s
# im_detect: 2978/3226 forward_pass_time: 0.0492s misc: 0.0432s
# im_detect: 2979/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2980/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2981/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2982/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2983/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2984/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2985/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2986/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2987/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2988/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2989/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2990/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2991/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2992/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2993/3226 forward_pass_time: 0.0491s misc: 0.0432s
# im_detect: 2994/3226 forward_pass_time: 0.0491s misc: 0.0431s
# im_detect: 2995/3226 forward_pass_time: 0.0491s misc: 0.0431s
# im_detect: 2996/3226 forward_pass_time: 0.0491s misc: 0.0431s
# im_detect: 2997/3226 forward_pass_time: 0.0491s misc: 0.0431s
# im_detect: 2998/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 2999/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3000/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3001/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3002/3226 forward_pass_time: 0.0490s misc: 0.0431s
# im_detect: 3003/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3004/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3005/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3006/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3007/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3008/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3009/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3010/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3011/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3012/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3013/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3014/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3015/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3016/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3017/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3018/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3019/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3020/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3021/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3022/3226 forward_pass_time: 0.0490s misc: 0.0432s
# im_detect: 3023/3226 forward_pass_time: 0.0489s misc: 0.0432s
# im_detect: 3024/3226 forward_pass_time: 0.0489s misc: 0.0432s
# im_detect: 3025/3226 forward_pass_time: 0.0489s misc: 0.0432s
# im_detect: 3026/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3027/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3028/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3029/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3030/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3031/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3032/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3033/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3034/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3035/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3036/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3037/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3038/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3039/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3040/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3041/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3042/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3043/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3044/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3045/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3046/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3047/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3048/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3049/3226 forward_pass_time: 0.0492s misc: 0.0433s
# im_detect: 3050/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3051/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3052/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3053/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3054/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3055/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3056/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3057/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3058/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3059/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3060/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3061/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3062/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3063/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3064/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3065/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3066/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3067/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3068/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3069/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3070/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3071/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3072/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3073/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3074/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3075/3226 forward_pass_time: 0.0491s misc: 0.0433s
# im_detect: 3076/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3077/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3078/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3079/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3080/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3081/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3082/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3083/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3084/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3085/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3086/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3087/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3088/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3089/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3090/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3091/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3092/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3093/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3094/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3095/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3096/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3097/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3098/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3099/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3100/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3101/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3102/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3103/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3104/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3105/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3106/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3107/3226 forward_pass_time: 0.0490s misc: 0.0433s
# im_detect: 3108/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3109/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3110/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3111/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3112/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3113/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3114/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3115/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3116/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3117/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3118/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3119/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3120/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3121/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3122/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3123/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3124/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3125/3226 forward_pass_time: 0.0489s misc: 0.0433s
# im_detect: 3126/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3127/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3128/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3129/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3130/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3131/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3132/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3133/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3134/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3135/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3136/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3137/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3138/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3139/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3140/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3141/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3142/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3143/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3144/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3145/3226 forward_pass_time: 0.0488s misc: 0.0433s
# im_detect: 3146/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3147/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3148/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3149/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3150/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3151/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3152/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3153/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3154/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3155/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3156/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3157/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3158/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3159/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3160/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3161/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3162/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3163/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3164/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3165/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3166/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3167/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3168/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3169/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3170/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3171/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3172/3226 forward_pass_time: 0.0487s misc: 0.0433s
# im_detect: 3173/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3174/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3175/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3176/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3177/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3178/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3179/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3180/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3181/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3182/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3183/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3184/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3185/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3186/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3187/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3188/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3189/3226 forward_pass_time: 0.0486s misc: 0.0433s
# im_detect: 3190/3226 forward_pass_time: 0.0486s misc: 0.0434s
# im_detect: 3191/3226 forward_pass_time: 0.0486s misc: 0.0434s
# im_detect: 3192/3226 forward_pass_time: 0.0486s misc: 0.0434s
# im_detect: 3193/3226 forward_pass_time: 0.0486s misc: 0.0434s
# im_detect: 3194/3226 forward_pass_time: 0.0486s misc: 0.0434s
# im_detect: 3195/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3196/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3197/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3198/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3199/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3200/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3201/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3202/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3203/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3204/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3205/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3206/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3207/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3208/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3209/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3210/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3211/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3212/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3213/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3214/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3215/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3216/3226 forward_pass_time: 0.0485s misc: 0.0434s
# im_detect: 3217/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3218/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3219/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3220/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3221/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3222/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3223/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3224/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3225/3226 forward_pass_time: 0.0484s misc: 0.0435s
# im_detect: 3226/3226 forward_pass_time: 0.0484s misc: 0.0435s
